# %%
import pandas as pd
from pathlib import Path

# %%
import sys
sys.path.append('..')
from src.data_processing import process_file

# %%
RAW_FILE = Path("../data/raw/2026.csv")

PROCESSED_FILE = Path(
    "../data/processed/mandi_2026_cleaned.csv"
)

QUALITY_REPORT_FILE = Path(
    "../outputs/reports/quality_report_2026.csv"
)

# %%
quality_report_df = process_file(
    RAW_FILE,
    PROCESSED_FILE,
    chunksize=100000
)
# Out:
# Processing chunk 1...
# Chunk 1 completed.
# Processing chunk 2...
# Chunk 2 completed.
# Processing chunk 3...
# Chunk 3 completed.
# Processing chunk 4...
# Chunk 4 completed.
# Processing chunk 5...
# Chunk 5 completed.
# Processing chunk 6...
# Chunk 6 completed.

# %%
quality_report_df.to_csv(
    QUALITY_REPORT_FILE,
    index=False
)
