# %%
import pandas as pd
from pathlib import Path

import sys
sys.path.append('..')
from src.database import (
    upload_csv_to_mysql
)

# %%
upload_csv_to_mysql(
    csv_path="../data/processed/commodity_statistics.csv",
    table_name="commodity_statistics"
)
# Out:
# 'commodity_statistics' uploaded successfully!

# %%
upload_csv_to_mysql(
    "../data/processed/commodity_monthly_price.csv",
    "commodity_monthly_price"
)
# Out:
# 'commodity_monthly_price' uploaded successfully!

# %%
upload_csv_to_mysql(
    "../data/processed/seasonal_price_summary.csv",
    "seasonal_price_summary"
)
# Out:
# 'seasonal_price_summary' uploaded successfully!

# %%
upload_csv_to_mysql(
    "../data/processed/state_commodity_price.csv",
    "state_commodity_price"
)
# Out:
# 'state_commodity_price' uploaded successfully!

# %%
upload_csv_to_mysql(
    "../data/processed/market_price_summary.csv",
    "market_price_summary"
)
# Out:
# 'market_price_summary' uploaded successfully!

# %%
upload_csv_to_mysql(
    "../data/processed/trend_analysis.csv",
    "trend_analysis"
)
# Out:
# 'trend_analysis' uploaded successfully!

# %%
upload_csv_to_mysql(
    "../data/processed/business_insights_summary.csv",
    "business_insights_summary"
)
# Out:
# 'business_insights_summary' uploaded successfully!
