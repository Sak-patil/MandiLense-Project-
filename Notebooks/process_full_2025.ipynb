# %%
import pandas as pd
from pathlib import Path

# %%
import sys
sys.path.append('..')
from src.data_processing import process_2025_file

# %%
RAW_FILE = Path("../data/raw/2025.csv")

PROCESSED_FILE = Path(
    "../data/processed/mandi_2025_cleaned.csv"
)

QUALITY_REPORT_FILE = Path(
    "../outputs/reports/quality_report_2025.csv"
)

# %%
quality_report_df = process_2025_file(
    RAW_FILE,
    PROCESSED_FILE,
    chunksize=100000
)
# Out:
# Processing chunk 1...
# Chunk 1 completed.
# Processing chunk 2...
# Chunk 2 completed.
# Processing chunk 3...
# Chunk 3 completed.
# Processing chunk 4...
# Chunk 4 completed.
# Processing chunk 5...
# Chunk 5 completed.
# Processing chunk 6...
# Chunk 6 completed.
# Processing chunk 7...
# Chunk 7 completed.
# Processing chunk 8...
# Chunk 8 completed.
# Processing chunk 9...
# Chunk 9 completed.
# Processing chunk 10...
# Chunk 10 completed.
# Processing chunk 11...
# Chunk 11 completed.
# Processing chunk 12...
# Chunk 12 completed.
# Processing chunk 13...
# Chunk 13 completed.
# Processing chunk 14...
# Chunk 14 completed.
# Processing chunk 15...
# Chunk 15 completed.
# Processing chunk 16...
# Chunk 16 completed.
# Processing chunk 17...
# Chunk 17 completed.
# Processing chunk 18...
# Chunk 18 completed.
# Processing chunk 19...
# Chunk 19 completed.
# Processing chunk 20...
# Chunk 20 completed.
# Processing chunk 21...
# Chunk 21 completed.
# Processing chunk 22...
# ...

# %%
quality_report_df.to_csv(
    QUALITY_REPORT_FILE,
    index=False
)
